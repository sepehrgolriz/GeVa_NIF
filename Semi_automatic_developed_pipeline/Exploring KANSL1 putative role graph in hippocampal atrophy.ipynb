# %% [markdown]
# # Exploring KANSL1 putative role graph in hippocampal atrophy

# %%
import sys
import hbp_knowledge
import pybel
from pybel.struct import get_subgraph_by_annotation_value
from pybel_jupyter import to_jupyter

# %%
graph = pybel.from_path('/home/skhatami/PycharmProjects/conib/hbp_knowledge/biomarkers/cdr_story.bel')
graph.summarize()
kansl = get_subgraph_by_annotation_value(graph, 'Paper', "Show")
# Out:
# KANSL1 Subgraph and CDR Story v1.0.0
# Number of Nodes: 127
# Number of Edges: 221
# Number of Citations: 18
# Number of Authors: 0
# Network Density: 1.38E-02
# Number of Components: 1
# Number of Warnings: 0

# %%
kansl.summarize()
# Out:
# None vNone
# Number of Nodes: 22
# Number of Edges: 36
# Number of Citations: 10
# Number of Authors: 0
# Network Density: 7.79E-02
# Number of Components: 1
# Number of Warnings: 0

# %%
to_jupyter(kansl)
